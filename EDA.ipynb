# %% [markdown]
# # Capstone Project- EDA Workbook
# Cary Mosley, May 2020

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import calendar, time
import datetime as dt
from datetime import date
from pandas.tseries.offsets import DateOffset
import numpy as np
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk import word_tokenize
import string, re 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("once")

# %% [markdown]
# ## Stock Data EDA

# %%
spy_df=pd.read_pickle('Data/spy_df')
vix_df=pd.read_pickle('Data/vix_df')
qqq_df=pd.read_pickle('Data/qqq_df')
iwm_df=pd.read_pickle('Data/iwm_df')

# %%
# graphing the closing prices for the SPY

spy_df.plot(title= 'SPY Close Price',figsize=(15,8))
plt.show()

# %%
vix_df.plot(title= 'VIX Close Price',figsize=(15,8))
plt.show()

# %%
qqq_df.plot(title= 'QQQ Close Price',figsize=(15,8))
plt.show()

# %%
iwm_df.plot(title= 'IWM Close Price',figsize=(15,8))
plt.show()

# %% [markdown]
# ## Sentiment Indicator EDA

# %% [markdown]
# ## NYT Article EDA
